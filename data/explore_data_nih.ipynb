# %%
import matplotlib.pyplot as plt
import configparser
from PIL import Image
import pandas as pd
import seaborn as sns
from data_util import process_data

config = configparser.ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %% [markdown]
# More analyzes can be found em https://www.kaggle.com/code/sbernadac/lung-deseases-data-analysis

# %% [markdown]
# # Images

# %%
image_dir = f"{config['nih']['data_dir']}/images_001/images/00000001_000.png"
image = Image.open(image_dir)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024>

# %%
image.size
# Out:
# (1024, 1024)

# %% [markdown]
# # Annotations

# %%
data = pd.read_csv(f"{config['nih']['labels']}")
data = process_data(data)
data
# Out:
# /Users/dilermando/dev/Fairness/data/data_util.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Path"] = data["Image Index"].map(all_image_paths.get)
#              Image Index         Finding Labels  Follow-up #  Patient ID  \
# 2       00000001_002.png  Cardiomegaly|Effusion            2           1
# 3       00000002_000.png             No Finding            0           2
# 20      00000005_007.png  Effusion|Infiltration            7           5
# 21      00000006_000.png             No Finding            0           6
# 22      00000007_000.png             No Finding            0           7
# ...                  ...                    ...          ...         ...
# ...

# %%
data.describe()
# Out:
#         Follow-up #    Patient ID   Patient Age  OriginalImage[Width  \
# count  24982.000000  24982.000000  24982.000000         24982.000000
# mean       2.478825  15226.787207     45.757385          2606.180490
# std        6.889546   8895.432113     16.660411           365.862187
# min        0.000000      1.000000      1.000000          1143.000000
# 25%        0.000000   7511.500000     34.000000          2500.000000
# 50%        0.000000  15013.500000     47.000000          2544.000000
# 75%        2.000000  23141.750000     58.000000          2992.000000
# max      183.000000  30805.000000     95.000000          3343.000000
#
#             Height]  OriginalImagePixelSpacing[x            y]  Unnamed: 11
# count  24982.000000                 24982.000000  24982.000000          0.0
# mean    2553.396045                     0.155568      0.155568          NaN
# std      403.728311                     0.017096      0.017096          NaN
# ...

# %%
print(
    len(data['Patient ID'].unique()),
    len(data['Finding Labels'].unique()),
    len(data['Follow-up #'].unique()),
    len(data['Patient Gender'].unique()),
    len(data['View Position'].unique())
)
# Out:
# 24982 298 91 2 2

# %% [markdown]
# # View Position

# %%
data['View Position'].value_counts()
# Out:
# View Position
# PA    20526
# AP     4456
# Name: count, dtype: int64

# %%
data['View Position'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Gender distribuiton

# %%
data['Patient Gender'].value_counts()
# Out:
# Patient Gender
# M    13464
# F    11518
# Name: count, dtype: int64

# %%
data['Patient Gender'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Gender and age

# %%
sex_map = {'F': 'Female', 'M': 'Male'}
data['Patient Gender'] = data['Patient Gender'].map(sex_map)

ax = sns.histplot(
    data,
    x="Patient Age", hue="Patient Gender",
    multiple="stack",
    palette=['#594C53', '#F2CEE2'],
    bins=20
    # palette="light:m_r"
)
ax.set_xticks(range(0, 100, 5))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# # Labels

# %%
data['Finding Labels'].str.get_dummies(sep="|").sum()
# Out:
# Atelectasis            2123
# Cardiomegaly            736
# Consolidation           589
# Edema                   207
# Effusion               2011
# Emphysema                57
# Fibrosis                130
# Hernia                   21
# Infiltration            948
# Mass                    393
# No Finding            20350
# Nodule                  339
# Pleural_Thickening      245
# Pneumonia               122
# Pneumothorax            130
# dtype: int64

# %%
data['Finding Labels'].str.get_dummies(sep="|").sum().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
data['Finding Labels'].str.get_dummies(sep="|").sum().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
data_dummies = pd.concat([data, data['Finding Labels'].str.get_dummies(sep="|")], axis=1)

# %% [markdown]
# ## Age and labels

# %%
ax = sns.histplot(
    data_dummies,
    x="Patient Age", hue="No Finding",
    multiple="stack",
    palette='mako',
    bins=20
    # palette="light:m_r"
)
ax.set_xticks(range(0, 100, 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb Célula 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> ax = sns.histplot(
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>     data_dummies,
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     x="Patient Age", hue="No Finding",
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a>     multiple="stack",
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/data/explore_data_nih.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>     palette='mako',
# ...

# %%
ax = sns.histplot(
    data_dummies,
    x="Patient Age", hue="Infiltration",
    multiple="stack",
    palette='mako',
    bins=20
    # palette="light:m_r"
)
ax.set_xticks(range(0, 100, 5))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
ax = sns.histplot(
    data_dummies,
    x="Patient Age", hue="Effusion",
    multiple="stack",
    palette='mako',
    bins=20
    # palette="light:m_r"
)
ax.set_xticks(range(0, 100, 5))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Gender and labels

# %%
data_dummies_gender = pd.concat([data['Patient Gender'], data['Finding Labels'].str.get_dummies(sep="|")], axis=1)

# %%
sns.catplot(x='Labels', y='Count', hue='Patient Gender', data=data_dummies_gender.melt(id_vars='Patient Gender', var_name='Labels', value_name='Count'), kind='bar')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
