# %%
import matplotlib.pyplot as plt
import configparser
from PIL import Image
import pandas as pd
import seaborn as sns
from data_util import process_data

config = configparser.ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %% [markdown]
# # Annotations

# %%
data = pd.read_csv(f"{config['brax']['labels']}")
data = process_data(data, dataset_name='brax')
data
# Out:
# /Users/dilermando/dev/Fairness/data/data_util.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PatientAge'] = data['PatientAge'].replace('85 or more', 85)
# /Users/dilermando/dev/Fairness/data/data_util.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PatientAge'] = data['PatientAge'].astype(int)
#        Unnamed: 0                                          DicomPath  \
# 6               6  Anonymized_DICOMs/id_f67bd3d2-ecba46b4-4f3a756...
# ...

# %%
data.iloc[1]['Path']
# Out:
# 'images/id_b201b4a3-97db3caf-10cdcfee-843d419c-cd18d1fc/Study_52165066.83205276.74614665.06359814.00029955/Series_21110632.37586182.33390805.14261466.95946811/image-92051337-45511530-67838913-64253710-42084416.png'

# %%
data.describe()
# Out:
#          Unnamed: 0   PatientAge  AccessionNumber     StudyDate   No Finding  \
# count   7254.000000  7254.000000     7.254000e+03  7.254000e+03  7254.000000
# mean   25345.302040    44.851117     4.958716e+07  2.012419e+07     0.765784
# std    10937.058527    19.008910     2.893455e+07  2.563003e+04     0.423537
# min        6.000000     5.000000     5.098000e+03  2.008040e+07     0.000000
# 25%    17282.500000    30.000000     2.448454e+07  2.010102e+07     1.000000
# 50%    27240.500000    45.000000     4.971412e+07  2.012071e+07     1.000000
# 75%    34716.250000    60.000000     7.471634e+07  2.015010e+07     1.000000
# max    40965.000000    85.000000     9.997479e+07  2.017122e+07     1.000000
#
#        Enlarged Cardiomediastinum  Cardiomegaly  Lung Lesion  Lung Opacity  \
# count                 6198.000000   7199.000000   292.000000    506.000000
# mean                     0.002097      0.087651     0.958904      0.982213
# ...

# %% [markdown]
# # View Position

# %%
data['ViewPosition'].value_counts()
# Out:
# ViewPosition
# PA    6974
# AP     280
# Name: count, dtype: int64

# %%
data['ViewPosition'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Gender distribuiton

# %%
data['PatientSex'].value_counts()
# Out:
# PatientSex
# F    3812
# M    3442
# Name: count, dtype: int64

# %%
data['PatientSex'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Gender and age

# %%
ax = sns.histplot(
    data,
    x="PatientAge", hue="PatientSex",
    multiple="layer",
    palette='mako',
    bins=16,
    kde=True
    # palette="light:m_r"
)
ax.set_xticks(range(0, 100, 5))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
