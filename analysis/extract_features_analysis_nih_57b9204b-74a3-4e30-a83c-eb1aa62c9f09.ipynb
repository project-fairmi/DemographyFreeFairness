# %%
import configparser
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import sys
sys.path.append('..')

from data.data_util import cluster_data, select_index

config = configparser.ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %%
dataset = 'nih'
id = "57b9204b-74a3-4e30-a83c-eb1aa62c9f09"
number_cluster_pca = 22
number_cluster_tsne = 22

# %%
tsne = np.load(f"{config['general']['experiment_dir']}/{id}/tsne_{dataset}_{id}.npy")
tsne.shape
# Out:
# (24982, 2)

# %%
plt.scatter(tsne[:, 0], tsne[:, 1], s=0.5)
plt.show()

# %%
data = pd.read_csv(f"{config[dataset]['labels']}")
data = select_index(data, id, dataset, tsne)

# %%
def categorize_age(age):
    if age < 15:
        return '0-15'
    elif 15 <= age < 30:
        return '15-30'
    elif 30 <= age < 45:
        return '30-45'
    elif 45 <= age < 60:
        return '45-60'
    elif 60 <= age < 75:
        return '60-75'
    elif 75 <= age < 90:
        return '75-90'
    # Add more categories as needed
    else:
        return '90+'
    
data['Patient Age'] = data['Patient Age'].apply(categorize_age)

# %%
sex_map = {'F': 'Female', 'M': 'Male'}
data['Patient Gender'] = data['Patient Gender'].map(sex_map)

# plot tsne with female and masculine
sns.jointplot(x="tsne_0", y="tsne_1",
                hue="Patient Gender",
                palette=['#594C53', '#F2CEE2'],
                sizes=(1, 8), linewidth=0,
                s=2,
                data=data)
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# plot tsne with female and masculine
age_categories_order = ['0-15', '15-30', '30-45', '45-60', '60-75', '75-90', '90+']
sns.jointplot(x="tsne_0", y="tsne_1",
                hue="Patient Age",
                hue_order=age_categories_order,
                palette='Set3',
                sizes=(1, 8), linewidth=0,
                s=2,
                data=data)

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.xlim(-100, 100)
plt.ylim(-100, 100)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sickness = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion', 'No Finding']

for s in sickness:
    # plot tsne with female and masculine
    sns.jointplot(x="tsne_x", y="tsne_y",
                    hue=s,
                    palette="tab10",
                    sizes=(1, 8), linewidth=0,
                    s=5,
                    data=data)
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel('t-SNE Dimension 2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dilermando/dev/Fairness/experiments/extract_features_analysis_nih.ipynb Célula 12 line 5
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/experiments/extract_features_analysis_nih.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> sickness = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion', 'No Finding']
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/experiments/extract_features_analysis_nih.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> for s in sickness:
#       <a href='vscode-notebook-cell:/Users/dilermando/dev/Fairness/experiments/extract_features_analysis_nih.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     # plot tsne with female and masculine
# ...

# %%
for s in sickness:
    sns.jointplot(x="pca_x", y="pca_y",
                    hue=s,
                    palette="tab10",
                    sizes=(1, 8), linewidth=0,
                    s=5,
                    data=data)
    plt.xlabel('PCA Dimension 1')
    plt.ylabel('PCA Dimension 2')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/fairness/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
